# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# OBS: the follwing chunk assumes that you've run the notebook `add_10_extra_words.ipynb`

# %%
data = pd.read_csv("wordlist_nlp.csv", sep=',')
xanew = pd.read_csv("Ratings_Warriner_et_al.csv", sep=',')
# Out:
# /tmp/ipykernel_2597/2218969650.py:2: DtypeWarning: Columns (67) have mixed types. Specify dtype option on import or set low_memory=False.
#   xanew = pd.read_csv("Ratings_Warriner_et_al.csv", sep=',')

# %%
# rename V.Mean.Sum column to Valence
data.rename(columns={'V.Mean.Sum': 'Valence'}, inplace=True)
xanew.rename(columns={'V.Mean.Sum': 'Valence'}, inplace=True)

data.rename(columns={'A.Mean.Sum': 'Arousal'}, inplace=True)
xanew.rename(columns={'A.Mean.Sum': 'Arousal'}, inplace=True)

# %%
display(data)
# Out:
#           word  ...1.x  sem_group  ...1.y  Valence  V.SD.Sum  V.Rat.Sum  \
# 0        abyss     249          0      46     3.90      1.51         21
# 1     accident     136         10      61     2.55      1.25         42
# 2    accordion     121          5      71     5.26      2.08         19
# 3          act      35         11     105     5.64      1.71         22
# 4        actor     142          7     113     6.15      1.27         20
# ..         ...     ...        ...     ...      ...       ...        ...
# 278      woman     225          7   13788     7.09      1.44         22
# 279     wonder     262          9   13792     6.68      1.70         22
# 280     worker      36          7   13811     5.95      1.47         20
# 281      world     176          2   13820     6.46      1.57         39
# 282        zoo     188         13   13913     7.00      1.58         21
#
#      Arousal  A.SD.Sum  A.Rat.Sum  ...  A.Rat.L  A.Mean.H  A.SD.H  A.Rat.H  \
# 0       4.85      2.41         20  ...       14      5.50    0.84        6
# 1       4.93      2.56         43  ...       24      4.74    2.42       19
# 2       2.94      2.21         18  ...       12      3.00    2.76        6
# 3       4.19      2.29         21  ...        6      4.00    1.81       15
# 4       4.35      2.28         20  ...       12      4.12    2.17        8
# ..       ...       ...        ...  ...      ...       ...     ...      ...
# 278     3.80      2.40         20  ...        6      4.36    2.50       14
# 279     4.38      2.60         21  ...        6      4.00    2.20       15
# 280     3.60      2.01         20  ...       10      3.60    2.32       10
# 281     4.55      2.30         42  ...       25      4.24    1.92       17
# 282     5.63      2.54         19  ...       13      5.17    2.14        6
#
#      D.Mean.L  D.SD.L  D.Rat.L  D.Mean.H  D.SD.H  D.Rat.H
# 0        3.42    2.57       12      4.78    2.77        9
# 1        2.85    2.31       26      3.18    1.89       22
# 2        5.27    2.25       15      5.11    1.96        9
# 3        5.70    2.21       10      6.62    1.77        8
# 4        5.64    2.29       11      5.64    1.75       11
# ..        ...     ...      ...       ...     ...      ...
# 278      6.62    2.07        8      5.14    1.46        7
# 279      6.80    2.97       10      6.00    1.93        8
# 280      6.47    2.07       17      5.86    1.46        7
# 281      5.38    2.63       16      4.96    2.41       25
# 282      5.67    2.87       12      7.22    1.86        9
#
# [283 rows x 67 columns]

# %%
# subset data only with word, valence and arousal column
data_sub = data[['word', 'Valence', 'Arousal']]
xanew_sub = xanew[['Word', 'Valence', 'Arousal']]

# %%
# rename word column in data_sub to Word
data_sub = data_sub.rename(columns={'word': 'Word'})

# %%
# add source column to data_sub with value "our_data"
data_sub['Source'] = 'our_data'
xanew_sub['Source'] = 'xanew'
# Out:
# /tmp/ipykernel_2597/1572930795.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xanew_sub['Source'] = 'xanew'

# %%
# concat data_sub and xanew_sub 
data_concat = pd.concat([data_sub, xanew_sub])

# %%
data_concat
# Out:
#             Word  Valence  Arousal    Source
# 0          abyss     3.90     4.85  our_data
# 1       accident     2.55     4.93  our_data
# 2      accordion     5.26     2.94  our_data
# 3            act     5.64     4.19  our_data
# 4          actor     6.15     4.35  our_data
# ...          ...      ...      ...       ...
# 13930   addition     5.65     3.60     xanew
# 13931     friday     7.70     6.70     xanew
# 13932   firework     4.75     3.75     xanew
# 13933  whiteness     6.95     7.60     xanew
# 13934  joviality     7.75     5.65     xanew
#
# [14218 rows x 4 columns]

# %%
# Plot 1: Valence density plot based on xanew_sub and data_sub
xanew_sub.Valence.plot.density(color="green")
plt.title('Plot 1: Density plot for valence based on xanew')
plt.show()

# %%
# Plot 2: Valence density plot based on data_sub
data_sub.Valence.plot.density(color="red")
plt.title('Plot 2: Density plot for valence based on our data')
plt.show()

# %%
# Arousal

# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above) 
sns.set(style="white",rc={"figure.figsize":(9,5)})

# plotting both distibutions on the same figure
fig = sns.kdeplot(xanew_sub['Arousal'], shade=True, color="#f06eb1")
fig = sns.kdeplot(data_sub['Arousal'], shade=True, color="#9dc779")

# add legend 
fig.legend(labels=['XANEW', 'Study Stimuli'])

# add title
fig.set_title("Arousal distribution, our stimuli and XANEW data")

# add vertical lines at x=3 and x = 6
fig.axvline(5, color='k', linestyle='--')


# add text to the vertical lines
fig.text(5.2, 0.11, 'High Arousal Cutoff', horizontalalignment='center', verticalalignment='center', rotation=90)


plt.show()

fig = fig.get_figure()
fig.savefig("arousal_dens.png")
# Out:
# /tmp/ipykernel_2597/3569361853.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   fig = sns.kdeplot(xanew_sub['Arousal'], shade=True, color="#f06eb1")
# /tmp/ipykernel_2597/3569361853.py:8: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   fig = sns.kdeplot(data_sub['Arousal'], shade=True, color="#9dc779")

# %%
# Valence plot

# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above) 
sns.set(style="white",rc={"figure.figsize":(9,5)})


# plotting both distibutions on the same figure
fig = sns.kdeplot(xanew_sub['Valence'], shade=True, color="#f06eb1",alpha=0.4)
fig = sns.kdeplot(data_sub['Valence'], shade=True, color="#9dc779",alpha=0.4)

# add legend 
fig.legend(labels=['XANEW', 'Study Stimuli'])

# add title
fig.set_title("Valence distribution, our stimuli and XANEW data")

# add vertical lines at x=3 and x = 6
fig.axvline(3, color='k', linestyle='--')
fig.axvline(6, color='k', linestyle='--')


# add text to the vertical lines
fig.text(2.9, 0.25, 'Low Valence Cutoff', horizontalalignment='center', verticalalignment='center', rotation=90)
fig.text(6.2, 0.1, 'Low Valence Cutoff', horizontalalignment='center', verticalalignment='center', rotation=90)


plt.show()

fig = fig.get_figure()
fig.savefig("valence_dens.png")
# Out:
# /tmp/ipykernel_2597/4014801973.py:8: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   fig = sns.kdeplot(xanew_sub['Valence'], shade=True, color="#f06eb1",alpha=0.4)
# /tmp/ipykernel_2597/4014801973.py:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   fig = sns.kdeplot(data_sub['Valence'], shade=True, color="#9dc779",alpha=0.4)
